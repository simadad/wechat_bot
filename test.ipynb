# %%
# %%cmd
# dir
# Out:
# Microsoft Windows [版本 6.1.7601]
# 版权所有 (c) 2009 Microsoft Corporation。保留所有权利。
#
# (itchat35) D:\Envs\itchat35\MyWechatBot>dir
#  驱动器 D 中的卷没有标签。
#  卷的序列号是 20DA-987C
#
#  D:\Envs\itchat35\MyWechatBot 的目录
#
# 2017/04/21 周五  16:58    <DIR>          .
# 2017/04/21 周五  16:58    <DIR>          ..
# 2017/03/17 周五  18:08               759 .gitignore
# 2017/04/21 周五  16:42    <DIR>          .idea
# 2017/04/21 周五  16:47    <DIR>          .ipynb_checkpoints
# 2017/03/27 周一  09:54               762 getMembers.py
# 2017/04/01 周六  12:55             1,855 getQA.py
# 2017/03/22 周三  11:16            11,098 members.xlsx
# 2017/03/31 周五  19:53               427 mybot.py
# 2017/04/01 周六  13:02             4,032 processor.py
# 2017/04/21 周五  14:31               716 QR.png
# 2017/04/21 周五  15:41             1,654 statistic.py
# 2017/04/21 周五  16:58             3,459 test.ipynb
# 2017/03/30 周四  13:54             1,281 test.py
# 2017/04/21 周五  14:31    <DIR>          __pycache__
# ...

# %%
from statistic import *
run()
plt.show()

# %%
plt.figure(1)
plt.axes(facecolor='k')
plt.plot([1,2,3,4,6,3,5,6,3], 'r-')
plt.annotate('aaaa', xy=(4, 6), xytext=(1, 4), color='b', arrowprops=dict(facecolor='b', shrink=0.01),)
plt.xticks([0,2,4,6,8])
plt.axis([-1, 10, 0, 8])

plt.figure(2)
plt.plot([5,3,6,3,2,2,5,7], 'g-')
plt.xticks([0,2,4,6,8])

plt.show()

# %%
from matplotlib import pyplot as plt
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['FangSong'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
plt.pie((1,2,3),explode=(0, 0.05, 0), labels=('啊', '吧', '初'), startangle=90, autopct='%3.1f%%')
plt.show()

# %%
plt.subplot(221)
plt.title('aa')
plt.subplot(222)
plt.title('bb')
plt.subplot(223)
plt.title('cc')
plt.show()

# %%
def func():
    yield 'aa'
    for i in range(5):
        yield i
        
f = func()
f1 = next(f)
for i in f:
    print(i)
print(f1)
# Out:
# 0
# 1
# 2
# 3
# 4
# aa

# %%
import openpyxl

wb = openpyxl.load_workbook('scheduled.xlsx')
ws = wb.active
now_schedule, now_line_pre = ws[2]
ws = ws[3:ws.max_row]
print(now_schedule.value, now_line_pre.value)
print(111)
for row in ws:
    print(row[0].value, row[1].value)
    schedule, content = row[0].value, row[1].value
# Out:
# 7-16 32;当前进度
# 111
# 1-4 完成python安装2.7.x 或 3.x 的最新版;能成功在控制台里运行python和pip命令;输出 'hello world'
# 2-2 选一个称手编辑器 （自带idle、推荐pycharm、sublime……）;最简单的输入输出
# 2-5 不同类型的输入方式（字符、数字）;输入提示的使用;不同类型的输出（字符、数字、计算式、比较大小）;一次输出多个不同的值;输出不换行;换行符的使用
# 3-3 参考阅读中的 变量，变量2(里面提及的循环可先略过);不同类型的变量变量的赋值、计算;+=
# 3-5 bool 类型;比较运算符;逻辑运算符
# 3-7 字符串类型;三种引号;字符串格式化
# 3-9 了解不同类型的差异;type方法;类型转换;不同类型转成bool值的结果
# 3-12 巩固基本概念：变量、类型、逻辑、字符串
# 4-2 if...elif...else;缩进;if嵌套
# 4-4 while循环;break
# 4-7 for循环;continue;循环嵌套
# 4-10 巩固程序中条件判断、循环的使用
# 4-11 实践循环的嵌套、数字和字符之间的处理
# 4-12 对输入数值进行判断后，按条件输出
# 5-2 import;random模块
# 5-5 练习模块的使用math、time
# 5-6 完善猜数字游戏的功能
# 6-4 函数的定义和使用;返回值;参数变量的作用域;（这一课涉及的函数内容稍多，可分2天完成）
# 6-4 函数的定义和使用;返回值;参数变量的作用域
# 6-7 巩固函数的相关概念
# 6-10 函数的应用
# 6-11 函数的应用2
# 7-3 列表的概念及常用操作;索引、切片、列表解析;（这一课涉及的函数内容稍多，可分2天完成）
# 7-3 列表的概念及常用操作;索引、切片、列表解析
# 7-6 巩固列表的概念
# 7-8 字符串分割成列表;列表拼接成字符串;字符串的索引和切片
# 7-12 字典、元组相关的概念及使用;（这一课涉及的函数内容稍多，可分2天完成）
# 7-12 字典、元组相关的概念及使用
# 7-15 序列的应用;随机数
# 7-16 序列的应用
# 8-2 读文件open;read/readlines
# 8-5 写文件;打开模式;异常处理
# ...
